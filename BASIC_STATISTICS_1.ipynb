# %% [markdown]
# ### **BASIC STATISTICS**

# %% [markdown]
# Descriptive Analytics and Data Preprocessing on Sales & Discounts Dataset
# Introduction
#
# ●	To perform descriptive analytics, visualize data distributions, and preprocess the dataset for further analysis.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded =files.upload()
# Out:
#      <input type="file" id="files-d73da32f-fdbb-4044-94bb-fe1607cc01bb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d73da32f-fdbb-4044-94bb-fe1607cc01bb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
sales = pd.read_csv('sales_data_with_discounts.csv')
sales
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB

# %%
# Mean
sales['Volume'].mean()
sales['Avg Price'].mean()
sales['Total Sales Value'].mean()
sales['Discount Rate (%)'].mean()
sales['Discount Amount'].mean()
sales['Net Sales Value'].mean()
print('Volume : ',sales['Volume'].mean())
print('Avg Price : ',sales['Avg Price'].mean())
print('Total Sales Value : ',sales['Total Sales Value'].mean())
print('Discount Rate (%) : ',sales['Discount Rate (%)'].mean())
print('Discount Amount : ',sales['Discount Amount'].mean())
print('Net Sales Value : ',sales['Net Sales Value'].mean())
# Out:
# Volume :  5.066666666666666
# Avg Price :  10453.433333333332
# Total Sales Value :  33812.83555555555
# Discount Rate (%) :  15.155241895330914
# Discount Amount :  3346.499424342415
# Net Sales Value :  30466.336131270138

# %%
# Meadian
sales['Volume'].median()
sales['Avg Price'].median()
sales['Total Sales Value'].median()
sales['Discount Rate (%)'].median()
sales['Discount Amount'].median()
sales['Net Sales Value'].median()
print('Volume : ',sales['Volume'].median())
print('Avg Price : ',sales['Avg Price'].median())
print('Total Sales Value : ',sales['Total Sales Value'].median())
print('Discount Rate (%) : ',sales['Discount Rate (%)'].median())
print('Discount Amount : ',sales['Discount Amount'].median())
print('Net Sales Value : ',sales['Net Sales Value'].median())
# Out:
# Volume :  4.0
# Avg Price :  1450.0
# Total Sales Value :  5700.0
# Discount Rate (%) :  16.57776564929597
# Discount Amount :  988.9337332382784
# Net Sales Value :  4677.788059301853

# %%
# Mode
sales['Volume'].mode()
sales['Avg Price'].mode()
sales['Total Sales Value'].mode()
sales['Discount Rate (%)'].mode()
sales['Discount Amount'].mode()
sales['Net Sales Value'].mode()
print('Volume : ',sales['Volume'].mode(),'\n')
print('Avg Price : ',sales['Avg Price'].mode(),'\n')
print('Total Sales Value : ',sales['Total Sales Value'].mode(),'\n')
print('Discount Rate (%) : ',sales['Discount Rate (%)'].mode(),'\n')
print('Discount Amount : ','\n',sales['Discount Amount'].mode(),'\n')
print('Net Sales Value : ',sales['Net Sales Value'].mode(),'\n')
# Out:
# Volume :  0    3
# Name: Volume, dtype: int64
#
# Avg Price :  0     400
# 1     450
# 2     500
# 3    1300
# 4    8100
# Name: Avg Price, dtype: int64
#
# Total Sales Value :  0    24300
# Name: Total Sales Value, dtype: int64
#
# Discount Rate (%) :  0       5.007822
# 1       5.055218
# 2       5.059801
# 3       5.072124
# 4       5.084108
#          ...
# 445    19.940610
# 446    19.965340
# 447    19.976879
# 448    19.982257
# 449    19.992407
# Name: Discount Rate (%), Length: 450, dtype: float64
#
# Discount Amount :
#  0         69.177942
# 1         73.025199
# 2         93.649161
# 3         94.682735
# 4        102.705757
#            ...
# 445    17900.983733
# 446    21153.498820
# 447    21496.675367
# 448    25328.224204
# 449    25738.022194
# Name: Discount Amount, Length: 450, dtype: float64
#
# Net Sales Value :  0         326.974801
# 1         330.822058
# 2         466.350839
# 3         485.317265
# 4         496.607104
#            ...
# ...

# %%
# Standard Deviation
sales['Volume'].std()
sales['Avg Price'].std()
sales['Total Sales Value'].std()
sales['Discount Rate (%)'].std()
sales['Discount Amount'].std()
sales['Net Sales Value'].std()
print('Volume',sales['Volume'].std())
print('Avg Price',sales['Avg Price'].std())
print('Total Sales Value',sales['Total Sales Value'].std())
print('Discount Rate (%)',sales['Discount Rate (%)'].std())
print('Discount Amount',sales['Discount Amount'].std())
# Out:
# Volume 4.231602391213923
# Avg Price 18079.90483993647
# Total Sales Value 50535.07417255325
# Discount Rate (%) 4.22060215332551
# Discount Amount 4509.902963353998

# %% [markdown]
# **Provide a brief interpretation of these statistics**
#
# With these statistics we can calculate the numerical values about the data that tells about the distribution of the data. we can also visualize the data in a easy way and less in time without worrying the size of the data. And we can error and outliers easily, can make quick decision on given data and simplify's the complex data.

# %% [markdown]
# # **Data Visualization**
# # Objective: To visualize the distribution and relationship of numerical and categorical variables in the dataset.

# %%
# Histograms :
plt.figure(figsize=(10,10))
plt.hist(sales['Volume'],edgecolor='black')
plt.title('Histogram of Numerical Variables')
plt.suptitle('Volume')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.hist(sales['Avg Price'],edgecolor='black')
plt.title('Histogram of Numerical Variables')
plt.suptitle('Avg Price')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.hist(sales['Total Sales Value'],edgecolor='black')
plt.title('Histogram of Numerical Variables')
plt.suptitle('Total Sales Value')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.hist(sales['Discount Rate (%)'],edgecolor='black')
plt.title('Histogram of Numerical Variables')
plt.suptitle('Discount Rate (%)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.hist(sales['Discount Amount'],edgecolor='black')
plt.title('Histogram of Numerical Variables')
plt.suptitle('Discount Amount')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.hist(sales['Net Sales Value'],edgecolor='black')
plt.title('Histogram of Numerical Variables')
plt.suptitle('Net Sales Value')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
# Analyze the distribution of 'Volume'
print("Volume distribution:")
print(sales['Volume'].describe())
print("Skewness:", sales['Volume'].skew())


# Analyze the distribution of 'Avg Price'
print("\nAvg Price distribution:")
print(sales['Avg Price'].describe())
print("Skewness:", sales['Avg Price'].skew())


# Analyze the distribution of 'Total Sales Value'
print("\nTotal Sales Value distribution:")
print(sales['Total Sales Value'].describe())
print("Skewness:", sales['Total Sales Value'].skew())


# Analyze the distribution of 'Discount Rate (%)'
print("\nDiscount Rate (%) distribution:")
print(sales['Discount Rate (%)'].describe())
print("Skewness:", sales['Discount Rate (%)'].skew())


# Analyze the distribution of 'Discount Amount'
print("\nDiscount Amount distribution:")
print(sales['Discount Amount'].describe())
print("Skewness:", sales['Discount Amount'].skew())


# Analyze the distribution of 'Net Sales Value'
print("\nNet Sales Value distribution:")
print(sales['Net Sales Value'].describe())
print("Skewness:", sales['Net Sales Value'].skew())


# Identify potential outliers using box plots
plt.figure(figsize=(10, 6))
sns.boxplot(data=sales[['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']])
plt.title('Box Plots of Numerical Variables')
plt.xticks(rotation=45)
plt.show()
# Out:
# Volume distribution:
# count    450.000000
# mean       5.066667
# std        4.231602
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        6.000000
# max       31.000000
# Name: Volume, dtype: float64
# Skewness: 2.731723626557714
#
# Avg Price distribution:
# count      450.000000
# mean     10453.433333
# std      18079.904840
# min        290.000000
# 25%        465.000000
# 50%       1450.000000
# 75%      10100.000000
# max      60100.000000
# Name: Avg Price, dtype: float64
# Skewness: 1.9088730767759727
#
# Total Sales Value distribution:
# count       450.000000
# mean      33812.835556
# std       50535.074173
# min         400.000000
# 25%        2700.000000
# 50%        5700.000000
# 75%       53200.000000
# max      196400.000000
# Name: Total Sales Value, dtype: float64
# Skewness: 1.5347293238977937
#
# Discount Rate (%) distribution:
# count    450.000000
# mean      15.155242
# std        4.220602
# min        5.007822
# 25%       13.965063
# ...

# %%
# BOX PLOT
plt.figure(figsize=(10, 6))
sns.boxplot(data=sales[['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']])
plt.title('Box Plots of Numerical Variables')
plt.xticks(rotation=45)
plt.show()

# %%
print("Interquartile Range (IQR) for each numerical variable:")
for col in sales.select_dtypes(include=np.number).columns:
  Q1 = sales[col].quantile(0.25)
  Q3 = sales[col].quantile(0.75)
  IQR = Q3 - Q1
  print(f"{col}: {IQR}")
# Out:
# Interquartile Range (IQR) for each numerical variable:
# Volume: 3.0
# Avg Price: 9635.0
# Total Sales Value: 50500.0
# Discount Rate (%): 4.149655934050962
# Discount Amount: 4856.03612280112
# Net Sales Value: 45645.70420627015

# %%
# Identify categorical columns
categorical_cols = sales.select_dtypes(include=['object']).columns
print("Categorical columns:", categorical_cols)
# Out:
# Categorical columns: Index(['Date'], dtype='object')

# %%
# Bar Chart Analysis for Categorical Column
sales[['Date']].value_counts().plot(kind='bar', color='grey',edgecolor='black', figsize=(10,5))
plt.show()

sales[['Day']].value_counts().plot(kind='bar',edgecolor='black')
plt.show()

# %%
sales[['City']].value_counts().plot(kind='bar',edgecolor='black')
plt.show()
sales[['SKU']].value_counts().plot(kind='bar',edgecolor='black', figsize=(10,5))
plt.show()

# %%
sales[['BU']].value_counts().plot(kind='bar',edgecolor='black')
plt.show()
sales[['Brand']].value_counts().plot(kind='bar',edgecolor='black')
plt.show()

# %%
sales[['Model']].value_counts().plot(kind='bar', color='skyblue',edgecolor='black',figsize=(10,10))
plt.show()

# %% [markdown]
# # **Standardization of Numerical Variables**

# %% [markdown]
# **Standardization :** Standardization, also known as Z-score normalization, is a technique used to scale features in a dataset so that they have the properties of a standard normal distribution. Specifically, the standardized data will have:
# A mean (average) of 0
# A standard deviation of 1
# This process ensures that the data is on the same scale, which is important for many machine learning algorithms that are sensitive to the relative magnitude of the features, such as support vector machines (SVM), k-nearest neighbors (k-NN), and principal component analysis (PCA).
# ​

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
numerical_columns = ['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']
numerical_columns
# Out:
# ['Volume',
#  'Avg Price',
#  'Total Sales Value',
#  'Discount Rate (%)',
#  'Discount Amount',
#  'Net Sales Value']

# %%
mean = sales[numerical_columns].mean()
std_dev = sales[numerical_columns].std()

# Apply the standardization formula
sales_standardized = (sales[numerical_columns] - mean) / std_dev

# Display the standardized data
print(sales_standardized)
# Out:
#        Volume  Avg Price  Total Sales Value  Discount Rate (%)  \
# 0    2.347417   0.091072           2.922469          -0.829365
# 1    1.165831  -0.019548           1.329516          -0.851714
# 2    0.456880   0.312312           1.561038          -1.350129
# 3    0.220563   0.533552           1.717365          -1.947555
# 4   -0.488389  -0.130168          -0.188242           0.672990
# ..        ...        ...                ...                ...
# 445 -0.724706  -0.506277          -0.617647           0.075924
# 446  0.220563  -0.434374          -0.360400           0.450596
# 447 -0.724706  -0.489684          -0.605774           0.902788
# 448 -0.488389  -0.473091          -0.556303           0.388042
# 449 -0.961023  -0.406719          -0.607753           0.042188
#
#      Discount Amount  Net Sales Value
# 0           3.948422         2.801638
# 1           1.846958         1.269613
# 2           1.621190         1.543957
# 3           1.112568         1.763847
# ...

# %%
for column in numerical_columns:
    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.hist(sales[column], bins=20, color='skyblue', edgecolor='black')
    plt.title(f'Distribution of {column} (Before Standardization)')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.subplot(1, 2, 2)
    plt.hist(sales_standardized[column], bins=20, color='salmon', edgecolor='black')
    plt.title(f'Distribution of {column} (After Standardization)')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # **Conversion of Categorical Data into Dummy Variables**

# %% [markdown]
# # ●	Objective: To transform categorical variables into a format that can be provided to ML algorithms.
# In many machine learning algorithms, categorical variables cannot be directly used as inputs. One-hot encoding is a technique used to convert categorical variables into a format that can be provided to machine learning algorithms.
# It creates binary (0 or 1) columns for each category in the categorical variable. This ensures that the categorical data is represented in a numerical format, allowing machine learning models to interpret and process it effectively.

# %%
sales.categorical_columns=['City', 'SKU', 'BU', 'Brand', 'Model', 'Day']
print(sales.categorical_columns)
# Out:
# ['City', 'SKU', 'BU', 'Brand', 'Model', 'Day']

# %%
sales = pd.get_dummies(sales.categorical_columns)
print(sales.head())
# Out:
#       BU  Brand   City    Day  Model    SKU
# 0  False  False   True  False  False  False
# 1  False  False  False  False  False   True
# 2   True  False  False  False  False  False
# 3  False   True  False  False  False  False
# 4  False  False  False  False   True  False

# %% [markdown]
# # Conclusion
# #### Key Findings from Descriptive Analytics and Data Visualizations
#
# 1. Numerical Columns:
#   The mean Volume of sales is 5.07 units, with a median of 4 units, indicating a slightly right-skewed distribution.
#    Total Sales Value has a mean of 33812.84 and a median of 5700, suggesting a right-skewed distribution with some transactions having
#      considerably higher sales values.
#   Discount Amount and Net Sales Value exhibit similar patterns, with a wide range of values and a right-skewed distribution.
#
# 2. Data Visualization:
#    Histograms and boxplots revealed the distribution and presence of outliers in numerical variables.
#    Bar charts for categorical columns illustrated the frequency of transactions in each category, providing insights into the distribution of
#      sales across different cities and brands.
#
# #### Reflection on the Importance of Data Preprocessing Steps
#
# 1. Standardization:
#    Standardizing numerical variables ensures that they are on the same scale improving the performance of analytical models. By scaling the data to have a mean of 0 and a standard deviation of 1, standardization facilitates accurate pattern recognition in the data.
#
# 2. One-Hot Encoding:
#    One-hot encoding transforms categorical variables into a numerical format suitable for machine learning algorithms.
#    This process enables models to interpret categorical data effectively and make accurate predictions based on the transformed dataset.
